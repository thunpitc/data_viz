# %% [markdown]
# <a href="https://colab.research.google.com/github/thunpitc/data_viz/blob/main/Quiz4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
P6364 = pd.read_excel('/content/passenger-covid19.xlsx',sheet_name=1)
P6364.head()
# Out:
#   ขนคน/ขนสินค้า โหมดการเดินทาง  ... 2021-04-11 00:00:00 2021-04-12 00:00:00
# 0     ขนคน (คน)          ทางบก  ...             70140.0             60013.0
# 1     ขนคน (คน)          ทางบก  ...                 NaN                 NaN
# 2     ขนคน (คน)          ทางบก  ...             15812.0             12359.0
# 3    ขนคน (คัน)          ทางบก  ...            895712.0            794519.0
# 4    ขนคน (คัน)          ทางบก  ...           1002653.0            884475.0
#
# [5 rows x 474 columns]

# %%
P6364['สาธารณะ/ส่วนบุคคล']
# Out:
# 0       สาธารณะ
# 1       สาธารณะ
# 2       สาธารณะ
# 3     ส่วนบุคคล
# 4     ส่วนบุคคล
# 5     ส่วนบุคคล
# 6     ส่วนบุคคล
# 7     ส่วนบุคคล
# 8       สาธารณะ
# 9       สาธารณะ
# 10      สาธารณะ
# 11      สาธารณะ
# 12      สาธารณะ
# 13    ส่วนบุคคล
# 14    ส่วนบุคคล
# 15      สาธารณะ
# 16      สาธารณะ
# 17      สาธารณะ
# 18      สาธารณะ
# 19    ส่วนบุคคล
# 20      สาธารณะ
# 21      สาธารณะ
# 22      สาธารณะ
# 23      สาธารณะ
# 24      สาธารณะ
# 25      สาธารณะ
# 26      สาธารณะ
# 27      สาธารณะ
# 28      สาธารณะ
# 29      สาธารณะ
# 30      สาธารณะ
# 31      สาธารณะ
# 32      สาธารณะ
# 33      สาธารณะ
# 34      สาธารณะ
# 35      สาธารณะ
# 36      สาธารณะ
# 37      สาธารณะ
# 38      สาธารณะ
# 39      สาธารณะ
# 40      สาธารณะ
# 41      สาธารณะ
# 42      สาธารณะ
# Name: สาธารณะ/ส่วนบุคคล, dtype: object
