# %% [markdown]
# <a href="https://colab.research.google.com/github/thunpitc/data_viz/blob/main/Quiz2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# เวลา 10 นาที
#
# https://data.go.th/dataset/item_7049410f-5bb8-4c75-9e94-112ca18b63e2

# %% [markdown]
# ![image.png](data:image/png;base64,...)
